# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
from textblob import TextBlob as tb

# %%
df=pd.read_csv("Downloads/comments.csv")
df
# Out:
#           Date   Time       form_id              From                Message  \
# 0   10-10-2020  10:22  6.090000e+14         Bhai Bhai                     hi
# 1   10-10-2020  10:22  6.090000e+14         Bhai Bhai                    bye
# 2   10-10-2020  10:29  2.460000e+15  Harsh Khandelwal   wow very nice post..
# 3   10-10-2020  10:30  6.090000e+14         Bhai Bhai         very beautiful
# 4   10-10-2020  10:31  6.090000e+14         Bhai Bhai              shut up??
# 5   10-10-2020  15:37  6.090000e+14         Bhai Bhai          your dumb ass
# 6   10-10-2020  18:03  4.090000e+14             Vidit          very bad post
# 7   10-10-2020  18:03  4.090000e+14             Vidit               bisexual
# 8   10-10-2020  18:04  2.460000e+15  Harsh Khandelwal             very funny
# 9   10-10-2020  10:30  5.060000e+15        Raj kapoor  thankyou so much dear
# 10  10-10-2020  10:45  4.090000e+14             Vidit            it is dirty
#
#     Likes  Comments  Comment id   Type
# 0       0         0          10   LIKE
# 1       0         1          20   LIKE
# 2       0         2          30   HAHA
# 3       0         0          40   LIKE
# 4       0         0          50   LIKE
# 5       0         0          60   LIKE
# 6       0         0          70  ANGRY
# 7       0         0          80  ANGRY
# 8       0         0          90   HAHA
# 9       0         0         100   LIKE
# 10      0         0         110  ANGRY

# %%
df1=pd.read_csv("Downloads/reactions.csv")
df1
# Out:
#         form_id              From   Type
# 0  6.090000e+14         Bhai Bhai   LIKE
# 1  2.460000e+15  Harsh Khandelwal   HAHA
# 2  4.090000e+14             Vidit  ANGRY
# 3  5.060000e+15        Raj Kapoor   LIKE

# %%
data=pd.read_csv("Downloads/data.csv")

# %%
df["form_id"]
# Out:
# 0     6.090000e+14
# 1     6.090000e+14
# 2     2.460000e+15
# 3     6.090000e+14
# 4     6.090000e+14
# 5     6.090000e+14
# 6     4.090000e+14
# 7     4.090000e+14
# 8     2.460000e+15
# 9     5.060000e+15
# 10    4.090000e+14
# Name: form_id, dtype: float64

# %%
merged = df.merge(df1, on='form_id')
del merged["From_y"]
merged.to_csv("output.csv", index=False)
merged
# Out:
#           Date   Time       form_id            From_x                Message  \
# 0   10-10-2020  10:22  6.090000e+14         Bhai Bhai                     hi
# 1   10-10-2020  10:22  6.090000e+14         Bhai Bhai                    bye
# 2   10-10-2020  10:30  6.090000e+14         Bhai Bhai         very beautiful
# 3   10-10-2020  10:31  6.090000e+14         Bhai Bhai              shut up??
# 4   10-10-2020  15:37  6.090000e+14         Bhai Bhai          your dumb ass
# 5   10-10-2020  10:29  2.460000e+15  Harsh Khandelwal   wow very nice post..
# 6   10-10-2020  18:04  2.460000e+15  Harsh Khandelwal             very funny
# 7   10-10-2020  18:03  4.090000e+14             Vidit          very bad post
# 8   10-10-2020  18:03  4.090000e+14             Vidit               bisexual
# 9   10-10-2020  10:45  4.090000e+14             Vidit            it is dirty
# 10  10-10-2020  10:30  5.060000e+15        Raj kapoor  thankyou so much dear
#
#     Likes  Comments  Comment id Type_x Type_y
# 0       0         0          10   LIKE   LIKE
# 1       0         1          20   LIKE   LIKE
# 2       0         0          40   LIKE   LIKE
# 3       0         0          50   LIKE   LIKE
# 4       0         0          60   LIKE   LIKE
# 5       0         2          30   HAHA   HAHA
# 6       0         0          90   HAHA   HAHA
# 7       0         0          70  ANGRY  ANGRY
# 8       0         0          80  ANGRY  ANGRY
# 9       0         0         110  ANGRY  ANGRY
# 10      0         0         100   LIKE   LIKE

# %%
positive=[]
negative=[]
neutral=[]
facts=[]
abusive=[]
others=[]

# %%
from __future__ import absolute_import
from collections import namedtuple
import nltk
from textblob.en import sentiment as pattern_sentiment
from textblob.tokenizers import word_tokenize
from textblob.decorators import requires_nltk_corpus
from textblob.base import BaseSentimentAnalyzer, DISCRETE, CONTINUOUS
from textblob import Blobber
from textblob.sentiments import NaiveBayesAnalyzer
nb = Blobber(analyzer=NaiveBayesAnalyzer())


def _default_feature_extractor(words):
    return dict(((word, True) for word in words))
class NaiveBayesAnalyzer(BaseSentimentAnalyzer):
    
    kind = DISCRETE
    RETURN_TYPE = namedtuple('Sentiment', ['classification', 'p_pos', 'p_neg'])
    def __init__(self, feature_extractor=_default_feature_extractor):
        super(NaiveBayesAnalyzer, self).__init__()
        self._classifier = None
        self.feature_extractor = feature_extractor
        @requires_nltk_corpus
        def train(self):
            """Train the Naive Bayes classifier on the movie review corpus."""
            super(NaiveBayesAnalyzer,self).train()
            neg_ids = nltk.corpus.movie_reviews.fileids('neg')
            pos_ids = nltk.corpus.movie_reviews.fileids('pos')
            neg_feats = [(self.feature_extractor( 
                nltk.corpus.movie_reviews.words(fileids=[f])), 'neg') for f in neg_ids]
            pos_feats = [(self.feature_extractor( 
                nltk.corpus.movie_reviews.words(fileids=[f])), 'pos') for f in pos_ids]
            train_data = neg_feats + pos_feats
            self._classifier = nltk.classify.NaiveBayesClassifier.train(train_data)
        def analyze(self, text):
            
            super(NaiveBayesAnalyzer,self).analyze(text)
            tokens = word_tokenize(text, include_punc=False)
            filtered = (t.lower() for t in tokens if len(t) >= 3)
            feats = self.feature_extractor(filtered)
            prob_dist = self._classifier.prob_classify(feats)
            return self.RETURN_TYPE(
                classification=prob_dist.max(),
                p_pos=prob_dist.prob('pos'),
                p_neg=prob_dist.prob("neg")
            )

# %%
comm=merged["Message"] +" "+merged["Type_x"]

reac=merged["Type_x"]
comm_id=merged["Comment id"]

for i in range(len(merged)):
    b=comm[i]
    flag=int(0)
    blob = tb(b)
    p=blob.detect_language()
    print(b)
    print(p)
    
    if(p!='en'):
        b=blob.translate(from_lang=p, to ='en')
        if(b.sentiment.polarity>0.30 and b.sentiment.subjectivity!=1):
            positive.append(comm_id[i])
            
        elif(b.sentiment.polarity==0 and b.sentiment.subjectivity!=1):
            neutral.append(comm_id[i])
            
        elif(b.sentiment.polarity<-0.25 and b.sentiment.subjectivity!=1):
            for row in data:
                if(row.lower() in b):
                    abusive.append(b)
                    flag=1;
                    break;
                if(flag==0):
                    negative.append(b)
        elif(b.sentiment.subjectivity>=0.75):
            facts.append(comm_id[i])
        else:
            others.append(comm_id[i])
            
        print(b.sentiment)
    else:
        if((nb(b).sentiment.p_pos - nb(b).sentiment.p_neg)>0.0):
            positive.append(comm_id[i])
        elif((nb(b).sentiment.p_pos - nb(b).sentiment.p_neg)<=0.01 and (nb(b).sentiment.p_pos - nb(b).sentiment.p_neg)>=0.01):
            neutral.append(comm_id[i])
        elif((nb(b).sentiment.p_pos - nb(b).sentiment.p_neg)<-0.25):
            for row in data:
                if(row.lower() in b):
                    abusive.append(b);
                    flag=1;
                    break;
            if(flag==0):
                negative.append(b)
        elif((nb(b).sentiment.p_pos - nb(b).sentiment.p_neg)>0.01 and (nb(b).sentiment.p_pos - nb(b).sentiment.p_neg)<0.25):
            facts.append(comm_id[i])
        else:
            others.append(comm_id[i])
        print(nb(b).sentiment)
# Out:
# hi LIKE
# en
# Sentiment(classification='neg', p_pos=0.483644859813084, p_neg=0.5163551401869159)
# bye LIKE
# en
# Sentiment(classification='neg', p_pos=0.400852052672347, p_neg=0.5991479473276535)
# very beautiful LIKE
# en
# Sentiment(classification='pos', p_pos=0.6541601543436537, p_neg=0.3458398456563463)
# shut up?? LIKE
# en
# Sentiment(classification='neg', p_pos=0.43258896584666856, p_neg=0.5674110341533315)
# your dumb ass LIKE
# en
# Sentiment(classification='neg', p_pos=0.16809966713532074, p_neg=0.831900332864679)
# wow very nice post.. HAHA
# en
# Sentiment(classification='neg', p_pos=0.3854309258938403, p_neg=0.6145690741061599)
# very funny HAHA
# en
# Sentiment(classification='pos', p_pos=0.523653936734975, p_neg=0.47634606326502493)
# very bad post ANGRY
# en
# Sentiment(classification='neg', p_pos=0.3460577990790839, p_neg=0.6539422009209162)
# bisexual ANGRY
# en
# Sentiment(classification='neg', p_pos=0.31925343811394874, p_neg=0.6807465618860512)
# it is dirty ANGRY
# en
# Sentiment(classification='pos', p_pos=0.5078125, p_neg=0.4921875000000004)
# thankyou so much dear LIKE
# en
# Sentiment(classification='neg', p_pos=0.4201101969350939, p_neg=0.5798898030649061)

# %%
neutral
# Out:
# []

# %%
facts
# Out:
# []

# %%
positive
# Out:
# [40, 90, 110]

# %%
negative
# Out:
# ['very bad post ANGRY']

# %%
abusive
# Out:
# ['your dumb ass LIKE', 'bisexual ANGRY']

# %%
others
# Out:
# [10, 20, 50, 30, 100]

# %%
p_positive=(len(positive)/len(merged))*100
p_negative=(np.unique(negative).size/len(merged))*100
p_neutral=(len(neutral)/len(merged))*100
p_facts=(len(facts)/len(merged))*100
p_abusive=(len(abusive)/len(merged))*100
p_others=(len(others)/len(merged))*100

# %%
print(str(p_positive) + "% people's comment was positive")
print(str(p_negative) + "% people's comment was negative")
print(str(p_neutral) + "% people's comment was neutral")
print(str(p_facts) + "% people's comment was fatcs")
print(str(p_abusive) + "% people's comment was abusive")
print(str(p_others) + "% people's comment was others(funny,sad...)")
# Out:
# 27.27272727272727% people's comment was positive
# 9.090909090909092% people's comment was negative
# 0.0% people's comment was neutral
# 0.0% people's comment was fatcs
# 18.181818181818183% people's comment was abusive
# 45.45454545454545% people's comment was others(funny,sad...)

# %%
height=[p_positive, p_negative, p_neutral, p_facts, p_abusive, p_others]
bars = ('Positive', 'Negative', 'Neutral', 'Facts', 'Abusive', 'Others')
y_pos=np.arange(len(bars))
plt.bar(y_pos, height, color = (0.5,0.1,0.5,0.6))
plt.title('Categories classification by Naive Bayes Algorithm')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.ylim(0,80)
plt.xticks(y_pos, bars)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
